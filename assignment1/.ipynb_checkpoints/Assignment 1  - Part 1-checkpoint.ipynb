# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv("./diamonds.csv")
diamonds = diamonds.drop(["Unnamed: 0"], axis=1)

# %% [markdown]
# ### 1. Data Summary

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
# carat      53940 non-null float64
# cut        53940 non-null object
# color      53940 non-null object
# clarity    53940 non-null object
# depth      53940 non-null float64
# table      53940 non-null float64
# price      53940 non-null int64
# x          53940 non-null float64
# y          53940 non-null float64
# z          53940 non-null float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ## 2. How to visualize price vs. cut: Continuous vs. Discrete

# %% [markdown]
# I would break the price data into each of the cut categories and then make a bar chart of each.

# %% [markdown]
# ## 3. So let's try it out!

# %%
# Subsample the data for each type of cut
keys = ["Fair", "Ideal", "Good","Very Good", "Premium"]
prices = dict()
for key in keys:
    prices[key] = diamonds.price[diamonds["cut"] == key]

# %%
# Plot all 3 in the same figure

subplots = [151, 152, 153, 154, 155]

plt.figure(1, figsize=(20,10))

for subplot, key in zip(subplots, keys):    
    plt.subplot(subplot)
    plt.xlabel(key + " Prices")
    plt.hist(premium_prices)

# %% [markdown]
# ### So what if I wanted to show the data in the same graph? (#4 too)
# Well, I'd use the same bar graph, but in each subsample, I would show the samples inside of the same bin together. But better yet (the first approach is pretty tedious for 5 graphs --> 1 graph), I'd try a boxplot.

# %%
plt.figure(2, figsize=(10,15))
ax = plt.subplot(111)
box = plt.boxplot([prices[key] for key in keys])
d = ax.set_xticklabels(keys)

# %% [markdown]
# ### 5. Analysis
# It doesn't seem like as the quality in cut increases, the price increases. Actually, the Fair diamonds have the highest average price.

# %% [markdown]
# ### 6. Clarity vs. Price

# %%
clar_keys = set(diamonds.clarity.values)
print len(clar_keys)
clarities = dict()
for key in clar_keys:
    clarities[key] = diamonds.price[diamonds["clarity"] == key]
# Out:
# 8

# %%
plt.figure(3, figsize=(10,15))
ax = plt.subplot(111)
box = plt.boxplot([clarities[key] for key in clar_keys])
d = ax.set_xticklabels(clar_keys)

# %% [markdown]
# ### 8. What makes the price high?

# %%
diamonds.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %% [markdown]
# It looks like carat is strongly correlated with price.

# %% [markdown]
# ### 9. Graphing cut, price, and carat

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
import numpy as np
cols = [.1,.3,.5,.7,.9]

for key, col in zip(keys, cols):
    ax1.scatter(diamonds.carat[diamonds["cut"] == key], diamonds.price[diamonds["cut"] == key],s=1, marker="s", label=key)
plt.legend(loc='lower right');
plt.xlabel("Carat")
plt.ylabel("Price")
plt.show()
